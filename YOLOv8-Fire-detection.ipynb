# %% [markdown]
# #  YOLOv8-Fire-detection

# %% [markdown]
# ## Training YOLOv8 based on fire storage

# %%
#from ultralytics import YOLO
 
 Load the model.
 model = YOLO('yolov8n.pt')
 
 Training.
 results = model.train(
    data=data_path\data.yaml",    
    imgsz=640,
    epochs=50,
    batch=8,
 )

# %% [markdown]
# ## Loading fire pre-trained model

# %%
from ultralytics import YOLO
model = YOLO('weight_path\fire.pt')

# %% [markdown]
# ## Prediction

# %%
from PIL import Image
# from PIL
im1 = Image.open('input image_path')
results = model.predict(source=im1, save=True)
# Out:
# 0: 608x640 1 FIRE, 112.7ms
# Speed: 6.0ms preprocess, 112.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# Results saved to runs\detect\predict3

# %% [markdown]
# ## Detection

# %%
display(Image.open('runs/detect/predict3/fire9.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=723x661>

# %%
from PIL import Image
# from PIL
im1 = Image.open('input image_path')
results = model.predict(source=im1, save=True)
# Out:
# 0: 480x640 4 FIREs, 121.7ms
# Speed: 6.0ms preprocess, 121.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict3

# %%
display(Image.open('runs/detect/predict3/fire4.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=927x684>
